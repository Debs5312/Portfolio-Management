# %%
# %load_ext autoreload
# %autoreload 2
import Edhec_risk_kit as erk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ind = erk.industry_dframe()
er = erk.periodic_returns(ind["1996":"2000"],12)
cov = ind["1996":"2000"].cov()

# %%
#For plotting N asset Frontier
erk.plot_NAsset_Frontier(20,er,cov)

# %%
#For plotting N asset Frontier with maximum sharp ratio
erk.plot_NAsset_Frontier(20,er,cov, show_CML=True,risk_free_rate=0.1)
